# %% [markdown]
# # Django dependencies

# %%
# !pip install django

# %%
# !pip install djangorestframework
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting djangorestframework
#   Downloading djangorestframework-3.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from djangorestframework) (2022.7.1)
# Requirement already satisfied: django>=3.0 in /usr/local/lib/python3.8/dist-packages (from djangorestframework) (4.1.7)
# Requirement already satisfied: asgiref<4,>=3.5.2 in /usr/local/lib/python3.8/dist-packages (from django>=3.0->djangorestframework) (3.6.0)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from django>=3.0->djangorestframework) (0.4.3)
# Requirement already satisfied: backports.zoneinfo in /usr/local/lib/python3.8/dist-packages (from django>=3.0->djangorestframework) (0.2.1)
# Installing collected packages: djangorestframework
# Successfully installed djangorestframework-3.14.0

# %%
# !pip install django-rest-knox
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting django-rest-knox
#   Downloading django_rest_knox-4.2.0-py3-none-any.whl (13 kB)
# Collecting cryptography
#   Downloading cryptography-39.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 77.4 MB/s eta 0:00:00
# Requirement already satisfied: django>=3.2 in /usr/local/lib/python3.8/dist-packages (from django-rest-knox) (4.1.7)
# Requirement already satisfied: djangorestframework in /usr/local/lib/python3.8/dist-packages (from django-rest-knox) (3.14.0)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from django>=3.2->django-rest-knox) (0.4.3)
# Requirement already satisfied: backports.zoneinfo in /usr/local/lib/python3.8/dist-packages (from django>=3.2->django-rest-knox) (0.2.1)
# Requirement already satisfied: asgiref<4,>=3.5.2 in /usr/local/lib/python3.8/dist-packages (from django>=3.2->django-rest-knox) (3.6.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography->django-rest-knox) (1.15.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from djangorestframework->django-rest-knox) (2022.7.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography->django-rest-knox) (2.21)
# Installing collected packages: cryptography, django-rest-knox
# Successfully installed cryptography-39.0.1 django-rest-knox-4.2.0

# %% [markdown]
# # Model dependencies

# %%
# !pip install translate

# %%
# !pip install ultralytics

# %% [markdown]
# # Running API Server

# %%
# !python /content/drive/MyDrive/api/manage.py makemigrations
# Out:
# No changes detected

# %%
# !python /content/drive/MyDrive/api/manage.py migrate
# Out:
# Operations to perform:
#   Apply all migrations: admin, auth, contenttypes, knox, sessions
# Running migrations:
#   No migrations to apply.

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://0otxdfngyuba-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %%
# !python /content/drive/MyDrive/api/manage.py runserver 8000
# Out:
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# February 26, 2023 - 18:04:57
# Django version 4.1.7, using settings 'api.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
# [26/Feb/2023 18:05:00] "GET / HTTP/1.1" 200 11250
# [26/Feb/2023 18:05:00] "GET /static/rest_framework/css/bootstrap.min.css HTTP/1.1" 200 121457
# [26/Feb/2023 18:05:00] "GET /static/rest_framework/css/bootstrap-tweaks.css HTTP/1.1" 200 3385
# [26/Feb/2023 18:05:00] "GET /static/rest_framework/css/default.css HTTP/1.1" 200 1152
# [26/Feb/2023 18:05:00] "GET /static/rest_framework/css/prettify.css HTTP/1.1" 200 817
# [26/Feb/2023 18:05:00] "GET /static/rest_framework/js/jquery-3.5.1.min.js HTTP/1.1" 200 89476
# [26/Feb/2023 18:05:00] "GET /static/rest_framework/js/bootstrap.min.js HTTP/1.1" 200 39680
# [26/Feb/2023 18:05:00] "GET /static/rest_framework/js/csrf.js HTTP/1.1" 200 1719
# [26/Feb/2023 18:05:01] "GET /static/rest_framework/js/ajax-form.js HTTP/1.1" 200 3597
# [26/Feb/2023 18:05:01] "GET /static/rest_framework/js/prettify-min.js HTTP/1.1" 200 13632
# [26/Feb/2023 18:05:01] "GET /static/rest_framework/js/default.js HTTP/1.1" 200 1268
# [26/Feb/2023 18:05:01] "GET /static/rest_framework/img/grid.png HTTP/1.1" 200 1458
# Not Found: /favicon.ico
# [26/Feb/2023 18:05:01] "GET /favicon.ico HTTP/1.1" 404 2286
# Ultralytics YOLOv8.0.47 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs
#
# 0: 640x640 1 person, 6096.2ms
# Speed: 3.5ms preprocess, 6096.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# [26/Feb/2023 18:05:17] "POST / HTTP/1.1" 200 205891
# [26/Feb/2023 18:05:18] "GET /static/rest_framework/css/bootstrap.min.css HTTP/1.1" 200 121457
# [26/Feb/2023 18:05:18] "GET /static/rest_framework/css/bootstrap-tweaks.css HTTP/1.1" 200 3385
# [26/Feb/2023 18:05:18] "GET /static/rest_framework/css/prettify.css HTTP/1.1" 200 817
# [26/Feb/2023 18:05:18] "GET /static/rest_framework/css/default.css HTTP/1.1" 200 1152
# [26/Feb/2023 18:05:18] "GET /static/rest_framework/js/jquery-3.5.1.min.js HTTP/1.1" 200 89476
# [26/Feb/2023 18:05:18] "GET /static/rest_framework/js/ajax-form.js HTTP/1.1" 200 3597
# [26/Feb/2023 18:05:18] "GET /static/rest_framework/js/csrf.js HTTP/1.1" 200 1719
# [26/Feb/2023 18:05:19] "GET /static/rest_framework/js/bootstrap.min.js HTTP/1.1" 200 39680
# [26/Feb/2023 18:05:19] "GET /static/rest_framework/js/prettify-min.js HTTP/1.1" 200 13632
# [26/Feb/2023 18:05:19] "GET /static/rest_framework/js/default.js HTTP/1.1" 200 1268
